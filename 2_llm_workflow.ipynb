# %% [markdown]
# # simple LLM calling for conversation
# ![workflow and states](images/llm-workflow.png)

# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state:LLMState)->LLMState:

    # have to extract the quetion from State

    question = state["question"]

    # form a prompt

    prompt = f"Answer the following question { question}"

    # ask the question to the LLM
    answer = model.invoke(prompt).content

    state["answer"] = answer

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node("llm_qa", llm_qa)

graph.add_edge(START, "llm_qa")
graph.add_edge("llm_qa", END)

workflow= graph.compile()

# %%
initial_state = {"question":"What is your name?"}

final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'question': 'What is your name?', 'answer': 'I am a language model AI assistant created by OpenAI, and I do not have a personal name. How can I assist you today?'}
