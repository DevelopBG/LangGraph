# %% [markdown]
# ![image.png](images/prompt-chain.png)

# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state:BlogState) -> BlogState:

    title = state["title"]

    # call llm to gen outline
    prompt = f"Generate a detailed outline for a blog on the topic {title}"

    outline = model.invoke(prompt).content
    
    state['outline'] = outline

    return state

def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f" Write a detailed blog on the title - {title} using the {outline}"

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes

graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow = graph.compile()

# %%
initial_state ={'title': "Rise of AI in India"}

final_state = workflow.invoke(initial_state)

# %%
print(final_state["content"])
# Out:
# The Rise of AI in India
#
# I. Introduction
#
# In today's rapidly evolving technological landscape, artificial intelligence (AI) has emerged as a powerful tool that is transforming industries across the globe. AI is the simulation of human intelligence processes by machines, particularly computer systems, with the ability to perform tasks such as learning, reasoning, problem-solving, and decision-making. The rise of AI in India is evident in the growing adoption of AI technologies in various sectors, including healthcare, finance, education, and more.
#
# II. Historical Background of AI in India
#
# India has a rich history of early developments and research in AI, dating back to the 1980s. The country has since seen a significant increase in the adoption of AI technology, with the growth of AI startups and companies in various cities such as Bangalore, Hyderabad, Pune, and Gurgaon. The Indian government has also taken proactive steps to promote the development of AI, with initiatives such as the National AI Strategy and Mission on AI.
#
# III. Current State of AI in India
#
# The AI market in India is rapidly expanding, with key players and stakeholders driving innovation and growth in the industry. AI has made a significant impact on sectors such as healthcare, finance, education, and ecommerce, with applications ranging from predictive analytics to personalized medicine. The potential of AI technology in India is vast, with opportunities for growth and innovation in various sectors.
#
# IV. Government Initiatives and Policies
#
# The Indian government has implemented several policies and initiatives to promote the development of AI in the country. Investments in AI research and development have increased, with a focus on supporting startups and fostering collaboration between academia and industry. However, challenges such as data privacy and security remain, requiring a comprehensive approach to ensure responsible AI development in India.
#
# V. Future Trends and Projections
#
# Emerging trends in AI technology in India include advancements in deep learning, natural language processing, and computer vision. Potential areas for growth and innovation in AI include robotics, autonomous vehicles, and smart cities. Projections for the future of AI in India are optimistic, with the potential to drive economic growth and improve the quality of life for millions of people.
#
# VI. Case Studies and Examples
#
# Successful AI startups in India, such as Niki.ai, Locus, and Niramai, are paving the way for innovation in the AI industry. Case studies of AI implementation in sectors such as healthcare, finance, and education are demonstrating the transformative impact of AI technology. However, concerns about the impact of AI on the job market and workforce in India remain, requiring proactive measures to ensure a smooth transition to an AI-driven economy.
#
# VII. Challenges and Ethical Considerations
#
# Challenges facing the AI industry in India include data privacy, bias in AI algorithms, and lack of regulatory frameworks. Ethical considerations, such as the impact of AI on jobs and society, require strategic planning and collaboration between stakeholders. Strategies to mitigate risks and ensure responsible AI development in India are essential to maximize the benefits of AI technology while minimizing potential harms.
#
# VIII. Conclusion
#
# In conclusion, the rise of AI in India presents exciting opportunities for growth and innovation across various sectors. The importance of AI technology in driving economic development and improving quality of life in India cannot be understated. As the country continues to embrace AI technology, it is essential to address challenges and ethical considerations to ensure a sustainable and inclusive AI ecosystem for the future.

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Explanation of what AI is
#     B. Overview of the rise of AI in India
#     C. Importance of AI technology in today's world
#
# II. Historical Background of AI in India
#     A. Early developments and research in AI in India
#     B. Adoption of AI technology in various sectors
#     C. Growth of AI startups and companies in India
#
# III. Current State of AI in India
#     A. Overview of the AI market in India
#     B. Key players and stakeholders in the AI industry
#     C. Impact of AI on various sectors such as healthcare, finance, education, etc.
#
# IV. Government Initiatives and Policies
#     A. Overview of government policies and initiatives to promote AI in India
#     B. Investments in AI research and development
#     C. Potential challenges and opportunities for AI growth in India
#
# V. Future Trends and Projections
#     A. Emerging trends in AI technology in India
#     B. Potential areas for growth and innovation in AI
#     C. Projections for the future of AI in India
#
# VI. Case Studies and Examples
#     A. Examples of successful AI startups in India
#     B. Case studies of AI implementation in various sectors
#     C. Impact of AI on job market and workforce in India
#
# VII. Challenges and Ethical Considerations
#     A. Challenges facing the AI industry in India
#     B. Ethical considerations of AI technology
#     C. Strategies to mitigate risks and ensure responsible AI development
#
# VIII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of AI technology in driving growth and innovation in India
#     C. Final thoughts on the future of AI in India.
