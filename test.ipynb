# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ayoubcherguelaine/company-documents-dataset")

print("Path to dataset files:", "D:\PROJECTS\LLM\LangGraph/")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# <>:6: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\banig\AppData\Local\Temp\ipykernel_9944\2496835693.py:6: SyntaxWarning: invalid escape sequence '\P'
#   print("Path to dataset files:", "D:\PROJECTS\LLM\LangGraph/")
# Path to dataset files: D:\PROJECTS\LLM\LangGraph/
